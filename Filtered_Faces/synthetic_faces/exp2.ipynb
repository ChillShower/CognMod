# %%
import pandas as pd
import matplotlib.pyplot as plt

ratings_amalie = pd.read_csv('image_reviews_amalie.csv')
ratings_simone = pd.read_csv('image_reviews_simone.csv')

ratings_amalie['true_rating'] = ratings_amalie['image'].str.extract(r"class_([0-9.]+)_weightmap.jpg").astype(float)
ratings_amalie['grade'] = ratings_amalie['grade'].astype(float)

ratings_simone['true_rating'] = ratings_simone['image'].str.extract(r"class_([0-9.]+)_weightmap.jpg").astype(float)
ratings_simone['grade'] = ratings_simone['grade'].astype(float)

# %%
ratings_amalie
# Out:
#                        image decision  grade  true_rating
# 0    class_2.5_weightmap.jpg     keep    2.0          2.5
# 1    class_2.0_weightmap.jpg     keep    3.0          2.0
# 2    class_0.5_weightmap.jpg     keep    2.0          0.5
# 3    class_4.0_weightmap.jpg     keep    3.0          4.0
# 4    class_3.5_weightmap.jpg     keep    1.0          3.5
# ..                       ...      ...    ...          ...
# 145  class_3.0_weightmap.jpg     keep    2.0          3.0
# 146  class_2.0_weightmap.jpg     keep    3.0          2.0
# 147  class_0.0_weightmap.jpg     keep    3.0          0.0
# 148  class_0.5_weightmap.jpg     keep    2.0          0.5
# 149  class_2.5_weightmap.jpg     keep    2.0          2.5
#
# [150 rows x 4 columns]

# %%
ratings_simone
# Out:
#                        image decision  grade  true_rating
# 0    class_2.5_weightmap.jpg     keep    2.0          2.5
# 1    class_2.0_weightmap.jpg     keep    3.0          2.0
# 2    class_0.5_weightmap.jpg     keep    2.0          0.5
# 3    class_4.0_weightmap.jpg     keep    3.0          4.0
# 4    class_3.5_weightmap.jpg     keep    1.0          3.5
# ..                       ...      ...    ...          ...
# 145  class_0.0_weightmap.jpg     keep    3.0          0.0
# 146  class_2.0_weightmap.jpg     keep    2.0          2.0
# 147  class_3.0_weightmap.jpg     keep    4.0          3.0
# 148  class_1.5_weightmap.jpg     keep    3.0          1.5
# 149  class_2.5_weightmap.jpg     keep    2.0          2.5
#
# [150 rows x 4 columns]

# %%
groups = [ratings_amalie[ratings_amalie['grade'] == p]['true_rating'].values for p in sorted(ratings_amalie['grade'].unique())]

plt.figure(figsize=(7,5))
plt.boxplot(groups, labels=sorted(ratings_amalie['grade'].unique()))
plt.xlabel("Predicted rating")
plt.ylabel("True rating")
plt.title("Participant 1")
plt.ylim(-1.0, 5.2)  # adjust if your rating scale is different
plt.show()
# Out:
# C:\Users\amali\AppData\Local\Temp\ipykernel_32132\1484104246.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=sorted(ratings_amalie['grade'].unique()))

# %%
groups = [ratings_simone[ratings_simone['grade'] == p]['true_rating'].values for p in sorted(ratings_simone['grade'].unique())]

plt.figure(figsize=(7,5))
plt.boxplot(groups, labels=sorted(ratings_simone['grade'].unique()))
plt.xlabel("Predicted rating")
plt.ylabel("True rating")
plt.title("Participant 2")
plt.ylim(-1.0, 5.2)  # adjust if your rating scale is different
plt.show()
# Out:
# C:\Users\amali\AppData\Local\Temp\ipykernel_32132\1670097206.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=sorted(ratings_simone['grade'].unique()))
